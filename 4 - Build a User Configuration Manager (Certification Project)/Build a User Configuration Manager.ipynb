# %%
# !git add .
# !git commit --m "Finished cert project"
# !git push
# Out:
# ...
# [main ebe60ee] Finished cert project
#  1 file changed, 91 insertions(+)
#  create mode 100644 4 - Build a User Configuration Manager/Build a User Configuration Manager.ipynb
# To https://github.com/JamesAlldred/freeCodeCamp_Python_Certification.git
#    5f46e18..ebe60ee  main -> main

# %%
test_settings = {
    'Theme': 'dark',
    'Notifications': 'enabled',
    'Volume': 'high',
}
tuple_settings = ('Brightness', 'low')

def add_setting(test_settings, tuple_settings):
    key, value = tuple_settings
    key = str(key).lower()
    value = str(value).lower()
    
    if key in test_settings:
        return f"Setting '{key}' already exists! Cannot add a new setting with this name."
    
    else:
        test_settings[key] = value
        return f"Setting '{key}' added with value '{value}' successfully!"

def update_setting(test_settings, tuple_settings):
    key, value = tuple_settings
    key = str(key).lower()
    value = str(value).lower()

    if key in test_settings:
        test_settings[key] = value
        return f"Setting '{key}' updated to '{value}' successfully!"
    
    else:
        return f"Setting '{key}' does not exist! Cannot update a non-existing setting."

def delete_setting(test_settings, key):
    key = str(key).lower()

    if key in test_settings:
        del test_settings[key]
        return f"Setting '{key}' deleted successfully!"
    
    else:
        return "Setting not found!"

def view_settings(test_settings):
    if not test_settings:
        return "No settings available."
    else:
        result = "Current User Settings:\n"
        for key, value in test_settings.items():
            result += f"{key.capitalize()}: {value}\n"
        return result

# %%
add_setting(test_settings, tuple_settings)
view_settings(test_settings)
# Out:
# 'Current User Settings:\nTheme: dark\nNotifications: enabled\nVolume: high\nBrightness: low\n'

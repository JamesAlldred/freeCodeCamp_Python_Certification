# %% [markdown]
# # Create a Hash Table

# %%
class HashTable:
    def __init__(self):
        self.collection = dict() # Initialise the hash table as an empty dictionary

    def hash(self, str): # Calculate the hash value of a string
        return sum(ord(char) for char in str) # Built in function to return unicode of a string

    def add(self, key, value):
        hashed_key = self.hash(key)
        if hashed_key in self.collection:
            self.collection[hashed_key][key] = value
        else:
            self.collection[hashed_key] = {key: value}

    def remove(self, key):
        hashed_key = self.hash(key)
        if hashed_key in self.collection and key in self.collection[hashed_key]:
            del self.collection[hashed_key][key]

    def lookup(self, key):
        hashed_key = self.hash(key)
        if hashed_key in self.collection and key in self.collection[hashed_key]:
            return self.collection[hashed_key][key]
        else:
            return None

# %% [markdown]
# # Algorithm problem solving techniques

# %% [markdown]
# ## Understand the problem

# %% [markdown]
# ## Break down the problem

# %% [markdown]
# ## Plan with pseudocode

# %% [markdown]
# ## Choose right algorithm

# %% [markdown]
# ## Consider data structures & edge cases

# %% [markdown]
# ## Implement, test & refine
